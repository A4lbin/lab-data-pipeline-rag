# %%
import pandas as pd
RAW_FILE = "../data/raw/4x4x4_SI.csv"
df=pd.read_csv(RAW_FILE)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'peptide', 'water', 'HAuCl4', 'hepes', 'Slot',
#        'LabwareType', 'WellCode', 'WellIndex', 'UID', 'peptide_name'],
#       dtype='str')

# %%
df.dtypes
# Out:
# Unnamed: 0        int64
# peptide         float64
# water             int64
# HAuCl4          float64
# hepes           float64
# Slot              int64
# LabwareType         str
# WellCode            str
# WellIndex         int64
# UID                 str
# peptide_name        str
# dtype: object

# %%
df.shape
# Out:
# (448, 11)

# %%
df.isna().sum()
# Out:
# Unnamed: 0      0
# peptide         0
# water           0
# HAuCl4          0
# hepes           0
# Slot            0
# LabwareType     0
# WellCode        0
# WellIndex       0
# UID             0
# peptide_name    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["peptide_name"].unique()
# Out:
# <StringArray>
# ['MZ2', 'MZ2R', 'Z2', 'PZ2', 'Z2M6I', 'Z2M246I', 'AG3']
# Length: 7, dtype: str

# %%
df.describe()
# Out:
#        Unnamed: 0     peptide  water      HAuCl4       hepes        Slot  \
# count  448.000000  448.000000  448.0  448.000000  448.000000  448.000000
# mean   223.500000    0.000082    1.0    0.000106    0.000278    4.250000
# std    129.470717    0.000075    0.0    0.000061    0.000419    0.433497
# min      0.000000    0.000000    1.0    0.000040    0.000000    4.000000
# 25%    111.750000    0.000030    1.0    0.000061    0.000008    4.000000
# 50%    223.500000    0.000065    1.0    0.000093    0.000055    4.000000
# 75%    335.250000    0.000117    1.0    0.000138    0.000325    4.250000
# max    447.000000    0.000200    1.0    0.000200    0.001000    5.000000
#
#         WellIndex
# count  448.000000
# mean    31.500000
# std     18.493605
# min      0.000000
# 25%     15.750000
# 50%     31.500000
# 75%     47.250000
# max     63.000000

# %%
df.groupby("peptide_name").peptide_name.value_counts()
# Out:
# peptide_name  Unnamed: 0  peptide   water  HAuCl4    hepes    Slot  LabwareType      WellCode  WellIndex  UID
# AG3           384         0.000040  1      0.000040  0.00000  4     corning-48-3548  A1        0          2021-12-29AG3_S4_A1      1
#               385         0.000089  1      0.000068  0.00010  4     corning-48-3548  B1        1          2021-12-29AG3_S4_B1      1
#               386         0.000200  1      0.000068  0.00000  4     corning-48-3548  C1        2          2021-12-29AG3_S4_C1      1
#               387         0.000000  1      0.000040  0.00010  4     corning-48-3548  D1        3          2021-12-29AG3_S4_D1      1
#               388         0.000040  1      0.000200  0.00000  4     corning-48-3548  E1        4          2021-12-29AG3_S4_E1      1
#                                                                                                                                   ..
# ...
